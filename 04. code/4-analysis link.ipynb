# %%
# As the data processing will be pretty expensive in computation terms,
# the process was made in the Google Colab workspace so the data is stored in Google Drive
# to process the data at a local level or using data from a different source,
# the rout must be changed

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#**********************************************************************************************
# @Name: Agrupamiento de demanda por dia, ruta, hora y link
# @Author: Team 21
# @Date: 2020/10/28 20:40:47
# @Help: 
#**********************************************************************************************

# Libraries Import ----------------------------------------------------------------------------
import datetime as dt                 # Date manipulation
import pandas as pd                   # Data manipulation
import numpy as np                    # Numeric manipulation
import os, glob                       # System management
from google.colab import data_table

# Transformation Process -----------------------------------------------------------------------
#1. Filtering by the FAR column == 'False'
#2. Aggregating the data:
#    - Datekey.
#    - CodigoRuta.
#    - Hour.
#    - Link.
#3. Summary:
#    - PaxUp sum
#    - PaxDw sum

# Development ----------------------------------------------------------------------------------

# Local path where the original files are in
path = "/content/drive/My Drive/ds4a-project/outputs/"

# Local path where the transformed files will be
path_to = "/content/drive/My Drive/ds4a-project/stats/pax_by_link/"

# List of files to process
lista_files = [f for f in os.listdir(path) if f.endswith('.csv')]

# %%
# Data transformation process
for l in lista_files:
    print("Cargando: " + l) # prints when the file is loaded
    # Read file
    df = pd.read_csv((path + l), 
                     decimal = ".",
                     usecols = ['DATEKEY', 'CODIGORUTA', 'HOUR', 'LINK', 'SUBENDELANTERA', 'SUBENTRASERA', 'BAJANDELANTERA', 'BAJANTRASERA', 'FAR'], 
                     keep_default_na = False)
    # convert to numeric
    df['SUBENDELANTERA'] = pd.to_numeric(df['SUBENDELANTERA'])
    df['SUBENTRASERA'] = pd.to_numeric(df['SUBENTRASERA'])
    df['BAJANDELANTERA'] = pd.to_numeric(df['BAJANDELANTERA'])
    df['BAJANTRASERA'] = pd.to_numeric(df['BAJANTRASERA'])
    # Filter by FAR
    #df = df[df['FAR'] == False]
    # add columns
    df['PAXUP'] = df['SUBENDELANTERA'] + df['SUBENTRASERA']
    df['PAXDW'] = df['BAJANDELANTERA'] + df['BAJANTRASERA']
    # Group by date, route, hour and link
    df = df.groupby(['DATEKEY', 'CODIGORUTA', 'HOUR', 'LINK'], as_index = False).agg(PAXUP = ('PAXUP', 'sum'), PAXDW = ("PAXDW", 'sum'))
    # save result
    df.to_csv(path_to + str(df.DATEKEY[0]) + '_pax_link.csv', index = False)
    print("Guardado: " + l) # print when the file is saved after transforming it
# Out:
# Cargando: 20191101.csv
# Guardado: 20191101.csv
# Cargando: 20191102.csv
# Guardado: 20191102.csv
# Cargando: 20191103.csv
# Guardado: 20191103.csv
# Cargando: 20191104.csv
# Guardado: 20191104.csv
# Cargando: 20191105.csv
# Guardado: 20191105.csv
# Cargando: 20191106.csv
# Guardado: 20191106.csv
# Cargando: 20191107.csv
# Guardado: 20191107.csv
# Cargando: 20191108.csv
# Guardado: 20191108.csv
# Cargando: 20191109.csv
# Guardado: 20191109.csv
# Cargando: 20191110.csv
# Guardado: 20191110.csv
# Cargando: 20191111.csv
# Guardado: 20191111.csv
# Cargando: 20191112.csv
# Guardado: 20191112.csv
# Cargando: 20191113.csv
# Guardado: 20191113.csv
# Cargando: 20191114.csv
# Guardado: 20191114.csv
# Cargando: 20191115.csv
# Guardado: 20191115.csv
# Cargando: 20191116.csv
# Guardado: 20191116.csv
# Cargando: 20191117.csv
# Guardado: 20191117.csv
# Cargando: 20191118.csv
# Guardado: 20191118.csv
# Cargando: 20191119.csv
# Guardado: 20191119.csv
# Cargando: 20191120.csv
# Guardado: 20191120.csv
# Cargando: 20191121.csv
# Guardado: 20191121.csv
# Cargando: 20191122.csv
# Guardado: 20191122.csv
# Cargando: 20191123.csv
# Guardado: 20191123.csv
# Cargando: 20191124.csv
# Guardado: 20191124.csv
# Cargando: 20191125.csv
# Guardado: 20191125.csv
# Cargando: 20191126.csv
# Guardado: 20191126.csv
# Cargando: 20191127.csv
# Guardado: 20191127.csv
# Cargando: 20191128.csv
# Guardado: 20191128.csv
# Cargando: 20191129.csv
# Guardado: 20191129.csv
# Cargando: 20191130.csv
# Guardado: 20191130.csv
# Cargando: 20200401.csv
# Guardado: 20200401.csv
# Cargando: 20200501.csv
# Guardado: 20200501.csv
# Cargando: 20200502.csv
# Guardado: 20200502.csv
# Cargando: 20200503.csv
# Guardado: 20200503.csv
# Cargando: 20200504.csv
# Guardado: 20200504.csv
# Cargando: 20200505.csv
# Guardado: 20200505.csv
# Cargando: 20200402.csv
# Guardado: 20200402.csv
# Cargando: 20200403.csv
# Guardado: 20200403.csv
# Cargando: 20200506.csv
# Guardado: 20200506.csv
# Cargando: 20200404.csv
# Guardado: 20200404.csv
# Cargando: 20200405.csv
# Guardado: 20200405.csv
# Cargando: 20200507.csv
# Guardado: 20200507.csv
# Cargando: 20200406.csv
# Guardado: 20200406.csv
# Cargando: 20200508.csv
# Guardado: 20200508.csv
# Cargando: 20200407.csv
# Guardado: 20200407.csv
# Cargando: 20200408.csv
# Guardado: 20200408.csv
# Cargando: 20200509.csv
# Guardado: 20200509.csv
# Cargando: 20200409.csv
# Guardado: 20200409.csv
# Cargando: 20200510.csv
# Guardado: 20200510.csv
# Cargando: 20200410.csv
# Guardado: 20200410.csv
# Cargando: 20200411.csv
# Guardado: 20200411.csv
# Cargando: 20200412.csv
# Guardado: 20200412.csv
# Cargando: 20200413.csv
# Guardado: 20200413.csv
# Cargando: 20200414.csv
# Guardado: 20200414.csv
# Cargando: 20200415.csv
# Guardado: 20200415.csv
# Cargando: 20200416.csv
# Guardado: 20200416.csv
# Cargando: 20200417.csv
# Guardado: 20200417.csv
# Cargando: 20200418.csv
# Guardado: 20200418.csv
# Cargando: 20200419.csv
# Guardado: 20200419.csv
# Cargando: 20200420.csv
# Guardado: 20200420.csv
# Cargando: 20200421.csv
# Guardado: 20200421.csv
# Cargando: 20200422.csv
# Guardado: 20200422.csv
# Cargando: 20200423.csv
# Guardado: 20200423.csv
# Cargando: 20200424.csv
# Guardado: 20200424.csv
# Cargando: 20200425.csv
# Guardado: 20200425.csv
# Cargando: 20200426.csv
# Guardado: 20200426.csv
# Cargando: 20200427.csv
# Guardado: 20200427.csv
# Cargando: 20200428.csv
# Guardado: 20200428.csv
# Cargando: 20191201.csv
# Guardado: 20191201.csv
# Cargando: 20200429.csv
# Guardado: 20200429.csv
# Cargando: 20200430.csv
# Guardado: 20200430.csv
# Cargando: 20191202.csv
# Guardado: 20191202.csv
# Cargando: 20191203.csv
# Guardado: 20191203.csv
# Cargando: 20191204.csv
# Guardado: 20191204.csv
# Cargando: 20191205.csv
# Guardado: 20191205.csv
# Cargando: 20200101.csv
# Guardado: 20200101.csv
# Cargando: 20191206.csv
# Guardado: 20191206.csv
# Cargando: 20191207.csv
# Guardado: 20191207.csv
# Cargando: 20200301.csv
# Guardado: 20200301.csv
# Cargando: 20200102.csv
# Guardado: 20200102.csv
# Cargando: 20200201.csv
# Guardado: 20200201.csv
# Cargando: 20191208.csv
# Guardado: 20191208.csv
# Cargando: 20200202.csv
# Guardado: 20200202.csv
# Cargando: 20200302.csv
# Guardado: 20200302.csv
# Cargando: 20200116.csv
# Guardado: 20200116.csv
# Cargando: 20200103.csv
# Guardado: 20200103.csv
# Cargando: 20191209.csv
# Guardado: 20191209.csv
# Cargando: 20200203.csv
# Guardado: 20200203.csv
# Cargando: 20200117.csv
# Guardado: 20200117.csv
# Cargando: 20200303.csv
# Guardado: 20200303.csv
# Cargando: 20200104.csv
# Guardado: 20200104.csv
# Cargando: 20191210.csv
# Guardado: 20191210.csv
# Cargando: 20200316.csv
# Guardado: 20200316.csv
# Cargando: 20200105.csv
# Guardado: 20200105.csv
# Cargando: 20200304.csv
# Guardado: 20200304.csv
# Cargando: 20200118.csv
# Guardado: 20200118.csv
# Cargando: 20200204.csv
# Guardado: 20200204.csv
# Cargando: 20200317.csv
# Guardado: 20200317.csv
# Cargando: 20200106.csv
# Guardado: 20200106.csv
# Cargando: 20200119.csv
# Guardado: 20200119.csv
# Cargando: 20191211.csv
# Guardado: 20191211.csv
# Cargando: 20200305.csv
# Guardado: 20200305.csv
# Cargando: 20200318.csv
# Guardado: 20200318.csv
# Cargando: 20200205.csv
# Guardado: 20200205.csv
# Cargando: 20200120.csv
# Guardado: 20200120.csv
# Cargando: 20200107.csv
# Guardado: 20200107.csv
# Cargando: 20200306.csv
# Guardado: 20200306.csv
# Cargando: 20200319.csv
# Guardado: 20200319.csv
# Cargando: 20191212.csv
# Guardado: 20191212.csv
# Cargando: 20200206.csv
# Guardado: 20200206.csv
# Cargando: 20200121.csv
# Guardado: 20200121.csv
# Cargando: 20191213.csv
# Guardado: 20191213.csv
# Cargando: 20200108.csv
# Guardado: 20200108.csv
# Cargando: 20200122.csv
# Guardado: 20200122.csv
# Cargando: 20200207.csv
# Guardado: 20200207.csv
# Cargando: 20191214.csv
# Guardado: 20191214.csv
# Cargando: 20200109.csv
# Guardado: 20200109.csv
# Cargando: 20191215.csv
# Guardado: 20191215.csv
# Cargando: 20200208.csv
# Guardado: 20200208.csv
# Cargando: 20200123.csv
# Guardado: 20200123.csv
# Cargando: 20200209.csv
# Guardado: 20200209.csv
# Cargando: 20200110.csv
# Guardado: 20200110.csv
# Cargando: 20191216.csv
# Guardado: 20191216.csv
# Cargando: 20200210.csv
# Guardado: 20200210.csv
# Cargando: 20191217.csv
# Guardado: 20191217.csv
# Cargando: 20191218.csv
# Guardado: 20191218.csv
# Cargando: 20191219.csv
# Guardado: 20191219.csv
# Cargando: 20191220.csv
# Guardado: 20191220.csv
# Cargando: 20191221.csv
# Guardado: 20191221.csv
# Cargando: 20191222.csv
# Guardado: 20191222.csv
# Cargando: 20191223.csv
# Guardado: 20191223.csv
# Cargando: 20191224.csv
# Guardado: 20191224.csv
# Cargando: 20191225.csv
# Guardado: 20191225.csv
# Cargando: 20191226.csv
# Guardado: 20191226.csv
# Cargando: 20191227.csv
# Guardado: 20191227.csv
# Cargando: 20191228.csv
# Guardado: 20191228.csv
# Cargando: 20200111.csv
# Guardado: 20200111.csv
# Cargando: 20191229.csv
# Guardado: 20191229.csv
# Cargando: 20200112.csv
# Guardado: 20200112.csv
# Cargando: 20191230.csv
# Guardado: 20191230.csv
# Cargando: 20200113.csv
# Guardado: 20200113.csv
# Cargando: 20200114.csv
# Guardado: 20200114.csv
# Cargando: 20191231.csv
# Guardado: 20191231.csv
# Cargando: 20200320.csv
# Guardado: 20200320.csv
# Cargando: 20200321.csv
# Guardado: 20200321.csv
# Cargando: 20200115.csv
# Guardado: 20200115.csv
# Cargando: 20200322.csv
# Guardado: 20200322.csv
# Cargando: 20200307.csv
# Guardado: 20200307.csv
# Cargando: 20200323.csv
# Guardado: 20200323.csv
# Cargando: 20200324.csv
# Guardado: 20200324.csv
# Cargando: 20200325.csv
# Guardado: 20200325.csv
# Cargando: 20200308.csv
# Guardado: 20200308.csv
# Cargando: 20200326.csv
# Guardado: 20200326.csv
# Cargando: 20200327.csv
# Guardado: 20200327.csv
# Cargando: 20200328.csv
# Guardado: 20200328.csv
# Cargando: 20200329.csv
# Guardado: 20200329.csv
# Cargando: 20200330.csv
# Guardado: 20200330.csv
# Cargando: 20200124.csv
# Guardado: 20200124.csv
# Cargando: 20200331.csv
# Guardado: 20200331.csv
# Cargando: 20200309.csv
# Guardado: 20200309.csv
# Cargando: 20200125.csv
# Guardado: 20200125.csv
# Cargando: 20200310.csv
# Guardado: 20200310.csv
# Cargando: 20200211.csv
# Guardado: 20200211.csv
# Cargando: 20200126.csv
# Guardado: 20200126.csv
# Cargando: 20200311.csv
# Guardado: 20200311.csv
# Cargando: 20200212.csv
# Guardado: 20200212.csv
# Cargando: 20200127.csv
# Guardado: 20200127.csv
# Cargando: 20200312.csv
# Guardado: 20200312.csv
# Cargando: 20200313.csv
# Guardado: 20200313.csv
# Cargando: 20200213.csv
# Guardado: 20200213.csv
# Cargando: 20200128.csv
# Guardado: 20200128.csv
# Cargando: 20200314.csv
# Guardado: 20200314.csv
# Cargando: 20200315.csv
# Guardado: 20200315.csv
# Cargando: 20200214.csv
# Guardado: 20200214.csv
# Cargando: 20200129.csv
# Guardado: 20200129.csv
# Cargando: 20200130.csv
# Guardado: 20200130.csv
# Cargando: 20200131.csv
# Guardado: 20200131.csv
# Cargando: 20200216.csv
# Guardado: 20200216.csv
# Cargando: 20200217.csv
# Guardado: 20200217.csv
# Cargando: 20200218.csv
# Guardado: 20200218.csv
# Cargando: 20200219.csv
# Guardado: 20200219.csv
# Cargando: 20200220.csv
# Guardado: 20200220.csv
# Cargando: 20200221.csv
# Guardado: 20200221.csv
# Cargando: 20200222.csv
# Guardado: 20200222.csv
# Cargando: 20200223.csv
# Guardado: 20200223.csv
# Cargando: 20200224.csv
# Guardado: 20200224.csv
# Cargando: 20200225.csv
# Guardado: 20200225.csv
# Cargando: 20200226.csv
# Guardado: 20200226.csv
# Cargando: 20200227.csv
# Guardado: 20200227.csv
# Cargando: 20200228.csv
# Guardado: 20200228.csv
# Cargando: 20200215.csv
# Guardado: 20200215.csv
# Cargando: 20200229.csv
# Guardado: 20200229.csv
